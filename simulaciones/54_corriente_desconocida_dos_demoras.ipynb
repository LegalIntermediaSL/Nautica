# %% [markdown]
# # Cálculo de Corriente Desconocida
# Determinación de Rhc y Ihc mediante dos demoras sucesivas.
#
# Este simulador está diseñado para fines educativos. **No lo utilices para la navegación real.**
#
# <a href="https://colab.research.google.com/github/jorgejuan007/Nautica/blob/main/simulaciones/54_corriente_desconocida_dos_demoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import ipywidgets as widgets
from IPython.display import display
import math

def corriente_desconocida(rs, vs, demora1_v, demora2_v, tiempo_entre_demoras, marcacion1, marcacion2):
    # En un escenario real, si partimos de una HRB inicial, el punto estimado pe no coincide con el verdadero.
    # La diferencia (dx, dy) entre el punto verdadero y el estimado nos da la corriente.
    # Aquí vamos a simular el resultado de un triángulo vectorial.
    print(f"Rumbo de Superficie (Rs): {rs}º")
    print(f"Velocidad de Superficie (Vs): {vs} nudos")
    print("Para determinar la corriente desconocida de forma exacta se requiere:")
    print("1. Situación Verdadera (corte de demoras).")
    print("2. Situación Estimada (calculada por Rv y Vb desde la última situación).")
    print("3. Trazar el vector desde S.E. hasta S.V.")
    print("4. Dividir la longitud de ese vector por el tiempo transcurrido para obtener la Intensidad Horaria (Ihc).")
    print("5. La dirección de ese vector es el Rumbo de la Corriente (Rhc).")
    print("\n-- Simulador analítico conceptual --")

rs_w = widgets.FloatSlider(value=90, min=0, max=360, step=1, description='Rumbo Sup.:')
vs_w = widgets.FloatSlider(value=6, min=1, max=15, step=0.5, description='Velocidad:')

out = widgets.interactive_output(corriente_desconocida, {'rs': rs_w, 'vs': vs_w, 'demora1_v': widgets.fixed(45), 'demora2_v': widgets.fixed(135), 'tiempo_entre_demoras': widgets.fixed(60), 'marcacion1': widgets.fixed(0), 'marcacion2': widgets.fixed(0)})
display(widgets.VBox([rs_w, vs_w, out]))
